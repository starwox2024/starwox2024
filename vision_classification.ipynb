# %% [markdown]
# ### Workflow Design
#
# 1. **Input Handling**
#    - Accept images as input.
#    - Check if the image needs to be converted to base64 encoding.
#
# 2. **Base64 Conversion**
#    - If required, convert the image to base64 encoding.
#
# 3. **Classification Criteria**
#    - Define a structured prompt that outlines the criteria for classification. For example:
#      - Image type (e.g., JPEG, PNG)
#      - Image content (e.g., cat, dog, car)
#      - Image quality (e.g., high, medium, low)
#
# 4. **Image Processing and Classification**
#    - Process each image according to the defined criteria.
#    - Classify the image based on the criteria.
#
# 5. **Structured Output**
#    - Store the results in a structured format (e.g., JSON).

# %% [markdown]
# ### Load the API key and relevant Python libraries

# %%
import os
import google.generativeai as genai

# %%
llm_model_g = 'gemini-1.5-flash'
GOOGLE_API_KEY = "AIzaSyBUSj-kqU1oZmdQUyuynrPjb1WHUNE1mRM"  # for genei
genai.configure(api_key=GOOGLE_API_KEY)

# %%
def get_completion_from_messages(messages,
                                 model_name="gemini-1.5-flash-002",
                                 temperature=0,
                                 max_tokens=500):
    model = genai.GenerativeModel(
    model_name,
    system_instruction=messages['system'],
    #temperature=temperature
    #max_tokens=max_tokens
    )

    prompt = messages['prompt']
    response = model.generate_content([prompt])

    return response.text

# %%
myfile = genai.upload_file("./test_pics/images (1).jpg")
print(f"{myfile=}")
# Out:
# myfile=genai.File({
#     'name': 'files/7njupk6cm5j7',
#     'display_name': 'images (1).jpg',
#     'mime_type': 'image/jpeg',
#     'sha256_hash': 'YzQwM2FlOWEyNDMzOTQwYjFjMWMxZGJkZjVhMDJmMWI1NGU3NWI4YWUzNWM4MWU1ZjI4MzMxYWNhYWFmMGIyNw==',
#     'size_bytes': '5441',
#     'state': 'ACTIVE',
#     'uri': 'https://generativelanguage.googleapis.com/v1beta/files/7njupk6cm5j7',
#     'create_time': '2024-11-15T10:57:30.747579Z',
#     'expiration_time': '2024-11-17T10:57:30.731233978Z',
#     'update_time': '2024-11-15T10:57:30.747579Z'})

# %%
import os

images_path = os.listdir("./test_pics")

# %%
return {
        "type": "JPEG",
        "content": "cat",
        "quality": "high"
    }

# %%
def classify_image(image_data):
    # Placeholder for actual classification logic
    # For example, you could use a pre-trained model to classify the image
    image_dic = {}
    for key, value in enumerate(images_path):
        my_file = genai.upload_file(f"./test_pics/{value}")
        image_dic[key] = my_file

    return image_dic

# %%
classify_image(images_path)
# Out:
# {0: genai.File({
#      'name': 'files/9sniv1fq0kc8',
#      'display_name': 'AF2bZyjYmpFxOE0vy_G8dqhhuFw77a4KHbat9SFxzhZniL3xYQ=s32-c-mo.jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'ZTk0MGI3OWYyMDJjZjZlNjE0YjI4OTM2ODdmMGRiNjc3ODZhNmYzMWFmNzllOWMzYjg0ZDI5NzFiMmExNjYyYw==',
#      'size_bytes': '1118',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/9sniv1fq0kc8',
#      'create_time': '2024-11-15T11:10:01.846441Z',
#      'expiration_time': '2024-11-17T11:10:01.827577479Z',
#      'update_time': '2024-11-15T11:10:01.846441Z'}),
#  1: genai.File({
#      'name': 'files/nb7qz2uvqfc5',
#      'display_name': 'images (1).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'YzQwM2FlOWEyNDMzOTQwYjFjMWMxZGJkZjVhMDJmMWI1NGU3NWI4YWUzNWM4MWU1ZjI4MzMxYWNhYWFmMGIyNw==',
#      'size_bytes': '5441',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/nb7qz2uvqfc5',
#      'create_time': '2024-11-15T11:10:05.219825Z',
#      'expiration_time': '2024-11-17T11:10:05.199018671Z',
#      'update_time': '2024-11-15T11:10:05.219825Z'}),
#  2: genai.File({
#      'name': 'files/43avidnmh00q',
#      'display_name': 'images (2).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'NjNkYThjZmZkMmUxZWQ2Y2ZlOGQwMzA0NTNhNDQ4YjNjOWI1ODIxOGUxMWQ3ZmMyYTFhZDRhYmRmNTgyMzU1OA==',
#      'size_bytes': '3898',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/43avidnmh00q',
#      'create_time': '2024-11-15T11:10:07.694636Z',
#      'expiration_time': '2024-11-17T11:10:07.678196655Z',
#      'update_time': '2024-11-15T11:10:07.694636Z'}),
#  3: genai.File({
#      'name': 'files/38qaprx4h58c',
#      'display_name': 'images (3).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'Y2FlMmE4OTRlYjQzODY4NjNjN2FhOTQ2ZDRkMWRkY2JkMjAxNTA4ODcwYzE3YjU3MGFjNzhjZWU5YTA0MTUwZA==',
#      'size_bytes': '5141',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/38qaprx4h58c',
#      'create_time': '2024-11-15T11:10:10.204930Z',
#      'expiration_time': '2024-11-17T11:10:10.185705581Z',
#      'update_time': '2024-11-15T11:10:10.204930Z'}),
#  4: genai.File({
#      'name': 'files/gcuzn8q8epst',
#      'display_name': 'images (4).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'ODVjMzc2OTlmNjc5YzBkYWVjNzg4Mzc2MDgzNTc0YTJiYzM2M2FkNmVhMDZmZDFmYWUwYWM4Y2Y3Yzg2MTcxNQ==',
#      'size_bytes': '2599',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/gcuzn8q8epst',
#      'create_time': '2024-11-15T11:10:12.477448Z',
#      'expiration_time': '2024-11-17T11:10:12.464633858Z',
#      'update_time': '2024-11-15T11:10:12.477448Z'}),
#  5: genai.File({
#      'name': 'files/k4mbhv808aft',
#      'display_name': 'images (5).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'MDE0ZjExNGUxYTUwNTM0NGYzMjdlZDI1Y2Y2ZmQ4ZWU1ODllMDU3YjlmNWM0NTJhZmJiMzk4YTQ3YjI0YzBiNQ==',
#      'size_bytes': '3542',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/k4mbhv808aft',
#      'create_time': '2024-11-15T11:10:14.843455Z',
#      'expiration_time': '2024-11-17T11:10:14.824324691Z',
#      'update_time': '2024-11-15T11:10:14.843455Z'}),
#  6: genai.File({
#      'name': 'files/abah7r39xlsx',
#      'display_name': 'images (6).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'MDEzYmVhMDBlNjg3NGZlNWJiMzdjNjJlNjc4NWYyYjAzNTJiM2M3ZGQwZTlkYTJhYjRlMTIzYjhkZGQxZDRlZA==',
#      'size_bytes': '3819',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/abah7r39xlsx',
#      'create_time': '2024-11-15T11:10:17.193267Z',
#      'expiration_time': '2024-11-17T11:10:17.171879954Z',
#      'update_time': '2024-11-15T11:10:17.193267Z'}),
#  7: genai.File({
#      'name': 'files/rsm6wd5px49c',
#      'display_name': 'images (7).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'ZmZmNDUyZDBjZjI5N2Q0YjgyMjA3MjdlYjgzNDlmMTQ2MWJmZWVmNzAwNjE1NjA5NmE2ODFmMDQ0MTAxZjRiYw==',
#      'size_bytes': '9493',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/rsm6wd5px49c',
#      'create_time': '2024-11-15T11:10:19.722450Z',
#      'expiration_time': '2024-11-17T11:10:19.710551298Z',
#      'update_time': '2024-11-15T11:10:19.722450Z'}),
#  8: genai.File({
#      'name': 'files/wm5zfsszxz0',
#      'display_name': 'images (8).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'ZDJhZmRlZTc5N2ZkMmZlMTE0NTdkNjkxZjgxMTJkYWVhNDgwODQzNDAyZmZmMzdkYTNlZjg0MzNhMmIxNzhjZQ==',
#      'size_bytes': '4840',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/wm5zfsszxz0',
#      'create_time': '2024-11-15T11:10:21.925658Z',
#      'expiration_time': '2024-11-17T11:10:21.913934832Z',
#      'update_time': '2024-11-15T11:10:21.925658Z'}),
#  9: genai.File({
#      'name': 'files/2h3pfxhq6mrv',
#      'display_name': 'images (9).jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'YTBjYTY1YmY0NGY3ZGQ3NWMzZTQ2ODBhYjZkYTQyZTE5MDEyMDhjMTUzYmEzZDNmMWRhMWQwMmExZWM3ZDNjMw==',
#      'size_bytes': '13327',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/2h3pfxhq6mrv',
#      'create_time': '2024-11-15T11:10:24.302529Z',
#      'expiration_time': '2024-11-17T11:10:24.290715814Z',
#      'update_time': '2024-11-15T11:10:24.302529Z'}),
#  10: genai.File({
#      'name': 'files/geveioitvgev',
#      'display_name': 'images.jpg',
#      'mime_type': 'image/jpeg',
#      'sha256_hash': 'NmIxOTlmY2M5MTllMmQzYjQ1MDRjYmJjY2I1MTRjNWI4NWEzNDU3NzllYzYzNzk2MTNmZDgzZjQ3NGI4MmUzOA==',
#      'size_bytes': '10591',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/geveioitvgev',
#      'create_time': '2024-11-15T11:10:26.709483Z',
#      'expiration_time': '2024-11-17T11:10:26.696475091Z',
#      'update_time': '2024-11-15T11:10:26.709483Z'}),
#  11: genai.File({
#      'name': 'files/88lig1y6ba8c',
#      'display_name': 'unsplash.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'MjliMGNlOWRkYzU1YzE1MTY0NjkyZTEzOWZmM2E5YTU3NTZlZjNmNzg1OTdjOTI4NTg3YWEyY2ZkODUyNTVjOQ==',
#      'size_bytes': '145',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/88lig1y6ba8c',
#      'create_time': '2024-11-15T11:10:28.855865Z',
#      'expiration_time': '2024-11-17T11:10:28.839973260Z',
#      'update_time': '2024-11-15T11:10:28.855865Z'}),
#  12: genai.File({
#      'name': 'files/s4t3kfsw6rsz',
#      'display_name': 'www.dreamstime.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'MjliNGZiODZkNGY2ZGEzZjNkMmE0MmM5MjgzOTVkNmNlYmFjZTU2YWIxN2YwOTE2MzZkN2ZjY2Q1OWEyNjM1Ng==',
#      'size_bytes': '411',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/s4t3kfsw6rsz',
#      'create_time': '2024-11-15T11:10:31.320087Z',
#      'expiration_time': '2024-11-17T11:10:31.308040798Z',
#      'update_time': '2024-11-15T11:10:31.320087Z'}),
#  13: genai.File({
#      'name': 'files/3a893xpyig2g',
#      'display_name': 'www.freepik.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'ZTIyZWFiZGU2YzFiNTBkYzY4Zjk3MDZhNzdhNjYxZDJjOTA2NGUxODI1NDc5MzZlMWRlNWE3OGJjMTQ4NDYwYQ==',
#      'size_bytes': '259',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/3a893xpyig2g',
#      'create_time': '2024-11-15T11:10:33.525614Z',
#      'expiration_time': '2024-11-17T11:10:33.505632848Z',
#      'update_time': '2024-11-15T11:10:33.525614Z'}),
#  14: genai.File({
#      'name': 'files/op5d1d2yp0uy',
#      'display_name': 'www.gettyimages.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'ZThjOWZlNDJkNDJiNTY4NzJjMmIyMDZkOGFmYmNhM2QyOWM1ODIzMWZlMGQ1YjczYmFjN2M2NWYwODZjNzcyZg==',
#      'size_bytes': '430',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/op5d1d2yp0uy',
#      'create_time': '2024-11-15T11:10:35.994063Z',
#      'expiration_time': '2024-11-17T11:10:35.977747594Z',
#      'update_time': '2024-11-15T11:10:35.994063Z'}),
#  15: genai.File({
#      'name': 'files/dpcpx8ryigh2',
#      'display_name': 'www.istockphoto.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'ZTJlYTdkYzY1NjM1YjBmMDRlYjdiMTk0ZDRkMGU1MGY0NzA5NTcxNjdhMGVjMTlkZjdlNzk5ZDkwZTBmNzQ2NA==',
#      'size_bytes': '218',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/dpcpx8ryigh2',
#      'create_time': '2024-11-15T11:10:38.309490Z',
#      'expiration_time': '2024-11-17T11:10:38.297231979Z',
#      'update_time': '2024-11-15T11:10:38.309490Z'}),
#  16: genai.File({
#      'name': 'files/uk2zxogj9mk2',
#      'display_name': 'www.nutritionadvance.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'NzJiZjg2YWQ1YTFlMDVkMzE0YzQyODQ5OTc4NGVkMTUyNTdlMjBiOThiY2JjNjEwYTg5YmY3MjE2MDBkNWQzMQ==',
#      'size_bytes': '576',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/uk2zxogj9mk2',
#      'create_time': '2024-11-15T11:10:40.622496Z',
#      'expiration_time': '2024-11-17T11:10:40.605169762Z',
#      'update_time': '2024-11-15T11:10:40.622496Z'}),
#  17: genai.File({
#      'name': 'files/m5yd0kuci2kc',
#      'display_name': 'www.pexels.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'ZmNhOTU2ZDBhZWE0MzE2MmFjZWFkYWM2MTM5OGEwZGE4Y2RmMjZlNmEwZTdmZGM5ZjNhYjc1MDRhYzZkN2JhOA==',
#      'size_bytes': '283',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/m5yd0kuci2kc',
#      'create_time': '2024-11-15T11:10:43.316997Z',
#      'expiration_time': '2024-11-17T11:10:43.304130620Z',
#      'update_time': '2024-11-15T11:10:43.316997Z'}),
#  18: genai.File({
#      'name': 'files/cwebx084ioyo',
#      'display_name': 'www.pinterest.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'MzlmODNjYmNlNGY3ZjY4MzY0ODQ5OWQxZWMwMmU0OWRmZTBjYzdhZTVhNGJiNDU5OWIwZDUxNzFkNGEyYzhkMg==',
#      'size_bytes': '343',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/cwebx084ioyo',
#      'create_time': '2024-11-15T11:10:45.886664Z',
#      'expiration_time': '2024-11-17T11:10:45.870747295Z',
#      'update_time': '2024-11-15T11:10:45.886664Z'}),
#  19: genai.File({
#      'name': 'files/710jqfr0jqgw',
#      'display_name': 'www.researchgate.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'NGY1NTQ5MzdlMGI1NTJiYmM0NGNhOWY3OTgyMDI0ODNiNDM0NTMxYjk3ODM4MzlmZmVjMjVkZTc1MjhhODkwMA==',
#      'size_bytes': '320',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/710jqfr0jqgw',
#      'create_time': '2024-11-15T11:10:48.280261Z',
#      'expiration_time': '2024-11-17T11:10:48.267906817Z',
#      'update_time': '2024-11-15T11:10:48.280261Z'}),
#  20: genai.File({
#      'name': 'files/fpm4wzkzw86n',
#      'display_name': 'www.shutterstock.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'MTE0NDMyYzA0YTk4NDc0NjA4ZWFmNTJiNWE5YzE5MmE5ZWIyMDc1ZmIxNzA5ZDE1ZmU5N2NhOGUzNmMxZGE2Zg==',
#      'size_bytes': '318',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/fpm4wzkzw86n',
#      'create_time': '2024-11-15T11:10:50.759384Z',
#      'expiration_time': '2024-11-17T11:10:50.747145799Z',
#      'update_time': '2024-11-15T11:10:50.759384Z'}),
#  21: genai.File({
#      'name': 'files/z73yqcfwqszw',
#      'display_name': 'www.youtube.png',
#      'mime_type': 'image/png',
#      'sha256_hash': 'YzJjOTIzNTFmYmQ5ZDE1YWIyNjhjNGY1NjYxMTg5ZGI1ZDNkYjFlZTMyNmRkYjA2MTMyNmQ1NzliM2Y5MDlmNw==',
#      'size_bytes': '343',
#      'state': 'ACTIVE',
#      'uri': 'https://generativelanguage.googleapis.com/v1beta/files/z73yqcfwqszw',
#      'create_time': '2024-11-15T11:10:53.191255Z',
#      'expiration_time': '2024-11-17T11:10:53.173267136Z',
#      'update_time': '2024-11-15T11:10:53.191255Z'})}

# %%
images = classify_image(images_path)

messages = {
            "system" : f"""
                You will be provided with a dictionary of some images and their features. \
                You are to pick the images with extensions jpg and jpeg only.
                Output the result in a json format.
                your answer should be in this format.
            
            """,

        "prompt" : f"""\
                   Classify the {images} using name, dispay and url       
                """
}

response = get_completion_from_messages(messages)
print(response)
# Out:
# ```json
# {
#   "jpg_jpeg_images": [
#     {
#       "name": "files/gc0vj3dgs6j1",
#       "display_name": "AF2bZyjYmpFxOE0vy_G8dqhhuFw77a4KHbat9SFxzhZniL3xYQ=s32-c-mo.jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "ZTk0MGI3OWYyMDJjZjZlNjE0YjI4OTM2ODdmMGRiNjc3ODZhNmYzMWFmNzllOWMzYjg0ZDI5NzFiMmExNjYyYw==",
#       "size_bytes": "1118",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/gc0vj3dgs6j1",
#       "create_time": "2024-11-15T11:49:23.789258Z",
#       "expiration_time": "2024-11-17T11:49:23.777733289Z",
#       "update_time": "2024-11-15T11:49:23.789258Z"
#     },
#     {
#       "name": "files/8fsgkd0v9eh8",
#       "display_name": "images (1).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "YzQwM2FlOWEyNDMzOTQwYjFjMWMxZGJkZjVhMDJmMWI1NGU3NWI4YWUzNWM4MWU1ZjI4MzMxYWNhYWFmMGIyNw==",
#       "size_bytes": "5441",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/8fsgkd0v9eh8",
#       "create_time": "2024-11-15T11:49:26.597565Z",
#       "expiration_time": "2024-11-17T11:49:26.580825929Z",
#       "update_time": "2024-11-15T11:49:26.597565Z"
#     },
#     {
#       "name": "files/p1wvg5tfa2i3",
#       "display_name": "images (2).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "NjNkYThjZmZkMmUxZWQ2Y2ZlOGQwMzA0NTNhNDQ4YjNjOWI1ODIxOGUxMWQ3ZmMyYTFhZDRhYmRmNTgyMzU1OA==",
#       "size_bytes": "3898",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/p1wvg5tfa2i3",
#       "create_time": "2024-11-15T11:49:28.565276Z",
#       "expiration_time": "2024-11-17T11:49:28.548381075Z",
#       "update_time": "2024-11-15T11:49:28.565276Z"
#     },
#     {
#       "name": "files/x2obsce8km12",
#       "display_name": "images (3).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "Y2FlMmE4OTRlYjQzODY4NjNjN2FhOTQ2ZDRkMWRkY2JkMjAxNTA4ODcwYzE3YjU3MGFjNzhjZWU5YTA0MTUwZA==",
#       "size_bytes": "5141",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/x2obsce8km12",
#       "create_time": "2024-11-15T11:49:30.542703Z",
#       "expiration_time": "2024-11-17T11:49:30.530036596Z",
#       "update_time": "2024-11-15T11:49:30.542703Z"
#     },
#     {
#       "name": "files/h0fodw2d0vzd",
#       "display_name": "images (4).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "ODVjMzc2OTlmNjc5YzBkYWVjNzg4Mzc2MDgzNTc0YTJiYzM2M2FkNmVhMDZmZDFmYWUwYWM4Y2Y3Yzg2MTcxNQ==",
#       "size_bytes": "2599",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/h0fodw2d0vzd",
#       "create_time": "2024-11-15T11:49:32.524980Z",
#       "expiration_time": "2024-11-17T11:49:32.503953061Z",
#       "update_time": "2024-11-15T11:49:32.524980Z"
#     },
#     {
#       "name": "files/918xdrpn9osk",
#       "display_name": "images (5).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "MDE0ZjExNGUxYTUwNTM0NGYzMjdlZDI1Y2Y2ZmQ4ZWU1ODllMDU3YjlmNWM0NTJhZmJiMzk4YTQ3YjI0YzBiNQ==",
#       "size_bytes": "3542",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/918xdrpn9osk",
#       "create_time": "2024-11-15T11:49:34.634136Z",
#       "expiration_time": "2024-11-17T11:49:34.618862966Z",
#       "update_time": "2024-11-15T11:49:34.634136Z"
#     },
#     {
#       "name": "files/keyqejo6hlwr",
#       "display_name": "images (6).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "MDEzYmVhMDBlNjg3NGZlNWJiMzdjNjJlNjc4NWYyYjAzNTJiM2M3ZGQwZTlkYTJhYjRlMTIzYjhkZGQxZDRlZA==",
#       "size_bytes": "3819",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/keyqejo6hlwr",
#       "create_time": "2024-11-15T11:49:36.592137Z",
#       "expiration_time": "2024-11-17T11:49:36.580009774Z",
#       "update_time": "2024-11-15T11:49:36.592137Z"
#     },
#     {
#       "name": "files/cgy9jcavc7bn",
#       "display_name": "images (7).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "ZmZmNDUyZDBjZjI5N2Q0YjgyMjA3MjdlYjgzNDlmMTQ2MWJmZWVmNzAwNjE1NjA5NmE2ODFmMDQ0MTAxZjRiYw==",
#       "size_bytes": "9493",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/cgy9jcavc7bn",
#       "create_time": "2024-11-15T11:49:38.530257Z",
#       "expiration_time": "2024-11-17T11:49:38.518188287Z",
#       "update_time": "2024-11-15T11:49:38.530257Z"
#     },
#     {
#       "name": "files/s6xb7m7x9as4",
#       "display_name": "images (8).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "ZDJhZmRlZTc5N2ZkMmZlMTE0NTdkNjkxZjgxMTJkYWVhNDgwODQzNDAyZmZmMzdkYTNlZjg0MzNhMmIxNzhjZQ==",
#       "size_bytes": "4840",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/s6xb7m7x9as4",
#       "create_time": "2024-11-15T11:49:40.498889Z",
#       "expiration_time": "2024-11-17T11:49:40.487379702Z",
#       "update_time": "2024-11-15T11:49:40.498889Z"
#     },
#     {
#       "name": "files/yj1om9sz2fve",
#       "display_name": "images (9).jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "YTBjYTY1YmY0NGY3ZGQ3NWMzZTQ2ODBhYjZkYTQyZTE5MDEyMDhjMTUzYmEzZDNmMWRhMWQwMmExZWM3ZDNjMw==",
#       "size_bytes": "13327",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/yj1om9sz2fve",
#       "create_time": "2024-11-15T11:49:42.521832Z",
#       "expiration_time": "2024-11-17T11:49:42.502245131Z",
#       "update_time": "2024-11-15T11:49:42.521832Z"
#     },
#     {
#       "name": "files/ls9jyfmpjujz",
#       "display_name": "images.jpg",
#       "mime_type": "image/jpeg",
#       "sha256_hash": "NmIxOTlmY2M5MTllMmQzYjQ1MDRjYmJjY2I1MTRjNWI4NWEzNDU3NzllYzYzNzk2MTNmZDgzZjQ3NGI4MmUzOA==",
#       "size_bytes": "10591",
#       "state": "ACTIVE",
#       "uri": "https://generativelanguage.googleapis.com/v1beta/files/ls9jyfmpjujz",
#       "create_time": "2024-11-15T11:49:44.607562Z",
#       "expiration_time": "2024-11-17T11:49:44.592794442Z",
#       "update_time": "2024-11-15T11:49:44.607562Z"
#     }
#   ]
# }
# ```

# %%
# messages = {
#         "system": f"""
#                     You will be provided with a list of images {image_dict}.\
#                     You are to describe each image first in memory.
#                     You are to classify each image under Product images and Lifestyle images.
#                     Your classification should be based on the content of the image.
#                     Do not classify by the name of the image according to its path.
#                     Product images are only having product items on them with no human beings.
#                     Lifestyle have both products with humans and sometimes only human beings.
#                     Lifestyle images show products in context, often with humans, natural backgrounds, or scenes conveying real-life usage.
#                     Ensure your classification is done accurately.
#                     Also state reasons and description for your classification.
#                     Output the result in a python json format.
#                         "Product Images" : image_details
#                         "Lifestyle Images" : image_details                  
#                 """,

#         "prompt": f"""\
#                         {image_dict}, "\n\n", lassify the images into Product Images amd Lifestyle Images stating the reasons for the classification
                    
#                     """
#     }

# %%
# # This path is also for testing
# from PIL import Image 
# # Load an image from a file 
# image_path = "./dowloaded_images" 
# image = Image.open(image_path) 
# # Display the image (optional) 
# image.show()

# %%
# This path is also for testing
#PIL.Image.open('./downloaded_images/image_110')
